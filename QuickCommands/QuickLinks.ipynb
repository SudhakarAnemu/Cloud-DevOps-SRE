# %% [markdown]
# <a href="https://colab.research.google.com/github/SudhakarAnemu/AI-DS-ML-DL-SRE-DRE/blob/master/QuickLinks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("js")
# Out:
# js

# %% [markdown]
# **Good urls**
#
# 1. https://stackedit.io/app#
# markdown editor:

# %% [markdown]
# **1. How to connect GCP VM via putty**
#
#
# *   Link : https://www.youtube.com/watch?v=euqEq87ZCCM
# *   Steps
#
#     1.   Generate private key(ppk) and publick key using putty gen at your laptop.
#     2.   Copy public key at the VM - Edit - SSH keys
#     3. Connect the VM via putty(mention private key at the auth)
#     4. Give user name the one you have given at the time of cretion of private key.
#     5. sudo su - : It will switch to Root
#
# 2. Install minikube on Ubuntu
#     a. https://www.linuxbuzz.com/install-minikube-on-ubuntu/
#
# 3. Install Kubernets on RHL8
#
#   a. https://srinirallabandi.medium.com/how-to-install-a-kubernetes-cluster-on-rhel-8-e35fc0d48efe

# %% [markdown]
# **minikube - Commands**
#
# 1. minikube version : verify the version
# 2. kubectl version -o yaml
# 3. kubectl version
# 4. minikube start --driver=docker
# 5. minikube status
# 6. minikube stop
# 7. minikube start
# 8. minikube addons list
# 9. minikube addons enable dashboard
#
# **kubectl - commands **
#
# 1. kubectl get nodes
# 2. kubectl cluster-info
# 3. kubectl create deployment nginx-web --image=nginx
# 4. kubectl expose deployment nginx-web --type NodePort --port=80
# 5. kubectl get deployment,pod,svc
#
# 1. Version
#
# root@minikube:~# minikube version
# minikube version: v1.32.0
# commit: 8220a6eb95f0a4d75f7f2d7b14cef975f050512d
# root@minikube:~#
#
# 2. Kubectl version :
#
#
# root@minikube:~# kubectl version -o yaml
# clientVersion:
#   buildDate: "2024-02-14T10:40:49Z"
#   compiler: gc
#   gitCommit: 4b8e819355d791d96b7e9d9efe4cbafae2311c88
#   gitTreeState: clean
#   gitVersion: v1.29.2
#   goVersion: go1.21.7
#   major: "1"
#   minor: "29"
#   platform: linux/amd64
# kustomizeVersion: v5.0.4-0.20230601165947-6ce0bf390ce3
#
# The connection to the server localhost:8080 was refused - did you specify the right host or port?
# root@minikube:~# kubectl version
# Client Version: v1.29.2
# Kustomize Version: v5.0.4-0.20230601165947-6ce0bf390ce3
# The connection to the server localhost:8080 was refused - did you specify the right host or port?
# root@minikube:~#
#
# 3. Start the minikube
#
# jssudha@minikube:~$ minikube start --driver=docker
# * minikube v1.32.0 on Ubuntu 20.04 (amd64)
# * Using the docker driver based on user configuration
# * Using Docker driver with root privileges
# * Starting control plane node minikube in cluster minikube
# * Pulling base image ...
# * Downloading Kubernetes v1.28.3 preload ...
#     > preloaded-images-k8s-v18-v1...:  403.35 MiB / 403.35 MiB  100.00% 221.55
#     > gcr.io/k8s-minikube/kicbase...:  453.90 MiB / 453.90 MiB  100.00% 88.09 M
# * Creating docker container (CPUs=2, Memory=2200MB) ...
# * Preparing Kubernetes v1.28.3 on Docker 24.0.7 ...
#   - Generating certificates and keys ...
#   - Booting up control plane ...
#   - Configuring RBAC rules ...
# * Configuring bridge CNI (Container Networking Interface) ...
#   - Using image gcr.io/k8s-minikube/storage-provisioner:v5
# * Verifying Kubernetes components...
# * Enabled addons: default-storageclass, storage-provisioner
# * Done! kubectl is now configured to use "minikube" cluster and "default" namespace by default
#
# 4. Check the status of the minikube
#
# jssudha@minikube:~$ minikube status
# minikube
# type: Control Plane
# host: Running
# kubelet: Running
# apiserver: Running
# kubeconfig: Configured
#
# jssudha@minikube:~$
#
# 5. get nodes
#
# jssudha@minikube:~$ kubectl get nodes
# NAME       STATUS   ROLES           AGE   VERSION
# minikube   Ready    control-plane   81s   v1.28.3
#
# 6. cluster information
#
# jssudha@minikube:~$ kubectl cluster-info
# Kubernetes control plane is running at https://192.168.49.2:8443
# CoreDNS is running at https://192.168.49.2:8443/api/v1/namespaces/kube-system/services/kube-dns:dns/proxy
#
# To further debug and diagnose cluster problems, use 'kubectl cluster-info dump'.
#
# 7. create a deployment
#
# jssudha@minikube:~$ kubectl create deployment nginx-web --image=nginx
# deployment.apps/nginx-web created
#
# 8. Expose a port
#
# jssudha@minikube:~$ kubectl expose deployment nginx-web --type NodePort --port=80
# service/nginx-web exposed
#
# 9. Get details of deployment, pod and services
#
# jssudha@minikube:~$ kubectl get deployment,pod,svc
# NAME                        READY   UP-TO-DATE   AVAILABLE   AGE
# deployment.apps/nginx-web   1/1     1            1           16s
#
# NAME                             READY   STATUS    RESTARTS   AGE
# pod/nginx-web-5b757f798d-77dcg   1/1     Running   0          16s
#
# NAME                 TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)        AGE
# service/kubernetes   ClusterIP   10.96.0.1       <none>        443/TCP        2m3s
# service/nginx-web    NodePort    10.96.141.142   <none>        80:30329/TCP   9s
# jssudha@minikube:~$
#
#
#
# 10. minikube addons list
#
# inikube:~$
# jssudha@minikube:~$ minikube addons list
#
# |-----------------------------|----------|--------------|--------------------------------|
# |         ADDON NAME          | PROFILE  |    STATUS    |           MAINTAINER           |
# |-----------------------------|----------|--------------|--------------------------------|
# | ambassador                  | minikube | disabled     | 3rd party (Ambassador)         |
# | auto-pause                  | minikube | disabled     | minikube                       |
# | cloud-spanner               | minikube | disabled     | Google                         |
# | csi-hostpath-driver         | minikube | disabled     | Kubernetes                     |
# | dashboard                   | minikube | disabled     | Kubernetes                     |
# | default-storageclass        | minikube | enabled ✅   | Kubernetes                     |
# | efk                         | minikube | disabled     | 3rd party (Elastic)            |
# | freshpod                    | minikube | disabled     | Google                         |
# | gcp-auth                    | minikube | disabled     | Google                         |
# | gvisor                      | minikube | disabled     | minikube                       |
# | headlamp                    | minikube | disabled     | 3rd party (kinvolk.io)         |
# | helm-tiller                 | minikube | disabled     | 3rd party (Helm)               |
# | inaccel                     | minikube | disabled     | 3rd party (InAccel             |
# |                             |          |              | [info@inaccel.com])            |
# | ingress                     | minikube | disabled     | Kubernetes                     |
# | ingress-dns                 | minikube | disabled     | minikube                       |
# | inspektor-gadget            | minikube | disabled     | 3rd party                      |
# |                             |          |              | (inspektor-gadget.io)          |
# | istio                       | minikube | disabled     | 3rd party (Istio)              |
# | istio-provisioner           | minikube | disabled     | 3rd party (Istio)              |
# | kong                        | minikube | disabled     | 3rd party (Kong HQ)            |
# | kubeflow                    | minikube | disabled     | 3rd party                      |
# | kubevirt                    | minikube | disabled     | 3rd party (KubeVirt)           |
# | logviewer                   | minikube | disabled     | 3rd party (unknown)            |
# | metallb                     | minikube | disabled     | 3rd party (MetalLB)            |
# | metrics-server              | minikube | disabled     | Kubernetes                     |
# | nvidia-device-plugin        | minikube | disabled     | 3rd party (NVIDIA)             |
# | nvidia-driver-installer     | minikube | disabled     | 3rd party (Nvidia)             |
# | nvidia-gpu-device-plugin    | minikube | disabled     | 3rd party (Nvidia)             |
# | olm                         | minikube | disabled     | 3rd party (Operator Framework) |
# | pod-security-policy         | minikube | disabled     | 3rd party (unknown)            |
# | portainer                   | minikube | disabled     | 3rd party (Portainer.io)       |
# | registry                    | minikube | disabled     | minikube                       |
# | registry-aliases            | minikube | disabled     | 3rd party (unknown)            |
# | registry-creds              | minikube | disabled     | 3rd party (UPMC Enterprises)   |
# | storage-provisioner         | minikube | enabled ✅   | minikube                       |
# | storage-provisioner-gluster | minikube | disabled     | 3rd party (Gluster)            |
# | storage-provisioner-rancher | minikube | disabled     | 3rd party (Rancher)            |
# | volumesnapshots             | minikube | disabled     | Kubernetes                     |
# |-----------------------------|----------|--------------|--------------------------------|
# jssudha@minikube:~$
#
# 11. Enable addons : dashboard and ingress
#
#
# jssudha@minikube:~$ minikube addons enable dashboard
# * dashboard is an addon maintained by Kubernetes. For any concerns contact minikube on GitHub.
# You can view the list of minikube maintainers at: https://github.com/kubernetes/minikube/blob/master/OWNERS
#   - Using image docker.io/kubernetesui/dashboard:v2.7.0
#   - Using image docker.io/kubernetesui/metrics-scraper:v1.0.8
# * Some dashboard features require the metrics-server addon. To enable all features please run:
#
#         minikube addons enable metrics-server
#
#
# * The 'dashboard' addon is enabled
# jssudha@minikube:~$ minikube addons enable ingress
# * ingress is an addon maintained by Kubernetes. For any concerns contact minikube on GitHub.
# You can view the list of minikube maintainers at: https://github.com/kubernetes/minikube/blob/master/OWNERS
#   - Using image registry.k8s.io/ingress-nginx/kube-webhook-certgen:v20231011-8b53cabe0
#   - Using image registry.k8s.io/ingress-nginx/controller:v1.9.4
#   - Using image registry.k8s.io/ingress-nginx/kube-webhook-certgen:v20231011-8b53cabe0
# * Verifying ingress addon...
# * The 'ingress' addon is enabled
# jssudha@minikube:~$
#
#
# 12. Stop and start

# %% [markdown]
# **Installation of Kubernets - master, node1 and node2**
# 1. Url : Install Kubernets on Ubuntu
# https://phoenixnap.com/kb/install-kubernetes-on-ubuntu
#
# 2. Install container d on worker nodes :
# https://www.techrepublic.com/article/install-containerd-ubuntu/
#
# 3. Useful urls
#  🇰https://github.com/cubensquare/K8S-v1.26-installation-containerd/blob/main/INSTALLATION%20STEPS.md
#
#  History from worker node : uid : jssudha 🇰
#
#  jssudha@worker01:~$ history
#     1  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#     2  which curl
#     3  echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/kubernetes.gpg] http://apt.kubernetes.io/ kubernetes-xenial main" | sudo tee -a /etc/apt/sources.list
#     4  sudo apt update
#     5  sudo su -
#     6  hostname
#     7  sudo systemctl stop apparmor && sudo systemctl disable apparmor
#     8  sudo systemctl restart containerd.service
#     9  sudo su -
#    10  kubectl get ndoes
#    11  kubectl get nodes
#    12  history
# jssudha@worker01:~$
#
# History : worker node : uid : root 🇰
#
#
# root@worker01:~#
# root@worker01:~# history
#     1  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#     2  cd /etc/apt/
#     3  mkdir keyrings
#     4  chmod 777 keyrings
#     5  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#     6  echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/kubernetes.gpg] http://apt.kubernetes.io/ kubernetes-xenial main" | sudo tee -a /etc/apt/sources.list
#     7  sudo apt update
#     8  sudo apt install kubeadm kubelet kubectl
#     9  sudo apt-mark hold kubeadm kubelet kubectl
#    10  kubeadm version
#    11  sudo swapoff -a
#    12  sudo sed -i '/ swap / s/^\(.*\)$/#\1/g' /etc/fstab
#    13  sudo nano /etc/modules-load.d/containerd.conf
#    14  cat -n /etc/modules-load.d/containerd.conf
#    15  sudo modprobe overlay
#    16  sudo modprobe br_netfilter
#    17  sudo nano /etc/sysctl.d/kubernetes.conf
#    18  cat -n /etc/sysctl.d/kubernetes.conf
#    19  sudo sysctl --system
#    20  hostname
#    21  ping 10.128.0.10
#    22  hostname
#    23  vi /etc/hosts
#    24  cat -n /etc/hosts
#    25  wget https://github.com/containerd/containerd/releases/download/v1.6.8/containerd-1.6.8-linux-amd64.tar.gz
#    26  sudo tar Cxzvf /usr/local containerd-1.6.8-linux-amd64.tar.gz
#    27  wget https://github.com/opencontainers/runc/releases/download/v1.1.3/runc.amd64
#    28  sudo install -m 755 runc.amd64 /usr/local/sbin/runc
#    29  wget https://github.com/containernetworking/plugins/releases/download/v1.1.1/cni-plugins-linux-amd64-v1.1.1.tgz
#    30  sudo mkdir -p /opt/cni/bin
#    31  sudo tar Cxzvf /opt/cni/bin cni-plugins-linux-amd64-v1.1.1.tgz
#    32  sudo mkdir /etc/containerd
#    33  containerd config default | sudo tee /etc/containerd/config.toml
#    34  sudo sed -i 's/SystemdCgroup \= false/SystemdCgroup \= true/g' /etc/containerd/config.toml
#    35  sudo curl -L https://raw.githubusercontent.com/containerd/containerd/main/containerd.service -o /etc/systemd/system/containerd.service
#    36  sudo systemctl daemon-reload
#    37  sudo systemctl enable --now containerd
#    38  sudo systemctl status containerd
#    39  sudo systemctl restart containerd.service
#    40  systemctl status containerd.service
#    41  sudo kubeadm join [master-node-ip]:6443 --token [token] --discovery-token-ca-cert-hash sha256:[hash]
#    42  kubeadm join master-node:6443 --token ks4nr1.js7gysfo54d91ad2         --discovery-token-ca-cert-hash sha256:e3114eb915cff253ae406f24a0fa1fe67926776333b5a51dd70b3b2c2cb16511
#    43  exit
#    44  clear
#    45  history
# root@worker01:~#
#
# History : master node : jssudha 🇰
#
#
# jssudha@master-node:~/.kube$
# jssudha@master-node:~/.kube$ history
#     1  sudo apt update
#     2  sudo apt install docker.io -y
#     3  sudo systemctl enable docker
#     4  sudo systemctl status docker
#     5  sudo systemctl stop docker
#     6  sudo systemctl start docker
#     7  sudo systemctl status docker
#     8  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#     9  echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/kubernetes.gpg] http://apt.kubernetes.io/ kubernetes-xenial main" | sudo tee -a /etc/apt/sources.list
#    10  sudo apt update
#    11  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg
#    12  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#    13  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg
#    14  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#    15  ls -l /etc/apt/keyrings/kubernetes.gpg
#    16  >/etc/apt/keyrings/kubernetes.gpg
#    17  cd /etc/apt/
#    18  cd keyrings
#    19  mkdir keyrings
#    20  sudo mkdir keyrings
#    21  sudo chmod 777 keyrings
#    22  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#    23  echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/kubernetes.gpg] http://apt.kubernetes.io/ kubernetes-xenial main" | sudo tee -a /etc/apt/sources.list
#    24  sudo apt update
#    25  sudo su -
#    26  sudo us -
#    27  hostname
#    28  sudo nano /etc/default/kubelet
#    29  cat -n /etc/default/kubelet
#    30  sudo systemctl daemon-reload && sudo systemctl restart kubelet
#    31  sudo nano /etc/docker/daemon.json
#    32  cat -n /etc/docker/daemon.json
#    33  sudo systemctl daemon-reload && sudo systemctl restart docker
#    34  sudo nano /etc/systemd/system/kubelet.service.d/10-kubeadm.conf
#    35  cat -n /etc/systemd/system/kubelet.service.d/10-kubeadm.conf
#    36  sudo systemctl daemon-reload && sudo systemctl restart kubelet
#    37  sudo kubeadm init --control-plane-endpoint=master-node --upload-certs
#    38  mkdir -p $HOME/.kube
#    39  sudo cp -i /etc/kubernetes/admin.conf $HOME/.kube/config
#    40  sudo chown $(id -u):$(id -g) $HOME/.kube/config
#    41  cd
#    42  cd .kube
#    43  ls -l
#    44  cat -n config
#    45  kubectl apply -f https://github.com/flannel-io/flannel/releases/latest/download/kube-flannel.yml
#    46  kubectl taint nodes --all node-role.kubernetes.io/control-plane-
#    47  top
#    48  kubectl get ndoes
#    49  kubectl get nodes
#    50  clear
#    51  history
# jssudha@master-node:~/.kube$
#
# History : root :  master node 🇰
#
#
# root@master-node:~# history
#     1  curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo gpg --dearmor -o /etc/apt/keyrings/kubernetes.gpg
#     2  echo "deb [arch=amd64 signed-by=/etc/apt/keyrings/kubernetes.gpg] http://apt.kubernetes.io/ kubernetes-xenial main" | sudo tee -a /etc/apt/sources.list
#     3  sudo apt update
#     4  sudo apt install kubeadm kubelet kubectl
#     5  sudo apt-mark hold kubeadm kubelet kubectl
#     6  kubeadm version
#     7  sudo swapoff -a
#     8  sudo sed -i '/ swap / s/^\(.*\)$/#\1/g' /etc/fstab
#     9  sudo nano /etc/modules-load.d/containerd.conf
#    10  cat -n /etc/modules-load.d/containerd.conf
#    11  sudo modprobe overlay
#    12  sudo modprobe br_netfilter
#    13  sudo nano /etc/sysctl.d/kubernetes.conf
#    14  cat -n /etc/sysctl.d/kubernetes.conf
#    15  sudo sysctl --system
#    16  hostname
#    17  cat -n /etc/hosts
#    18  hostname
#    19  vi /etc/hosts
#    20  cat -n /etc/hosts
#    21  clear
#    22  history
# root@master-node:~#
#
# Final output 🇰
#
# jssudha@master-node:~/.kube$ kubectl get nodes
# NAME          STATUS   ROLES           AGE     VERSION
# master-node   Ready    control-plane   29m     v1.28.2
# worker01      Ready    <none>          5m54s   v1.28.2
# worker02      Ready    <none>          5m51s   v1.28.2
# jssudha@master-node:~/.kube$ date
# Sat Mar  2 18:36:27 UTC 2024
# jssudha@master-node:~/.kube$
